# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents\\Batch 93 Day26'

# %%
os.chdir('C:\\Users\\HP\\Documents\\Batch 93 Day26\\')

# %%
tips=pd.read_csv('tips.csv')
tips1=tips
print(tips1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=tips1,x='day',y='total_bill')
plt.show()

# %%
print(tips[tips1['day']=='Fri'].describe())
# Out:
#        total_bill        tip       size
# count   19.000000  19.000000  19.000000
# mean    17.151579   2.734737   2.105263
# std      8.302660   1.019577   0.567131
# min      5.750000   1.000000   1.000000
# 25%     12.095000   1.960000   2.000000
# 50%     15.380000   3.000000   2.000000
# 75%     21.750000   3.365000   2.000000
# max     40.170000   4.730000   4.000000

# %%
sns.displot(tips1[tips['day']=='Fri']['total_bill'],kde=True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(tips1['total_bill'],kde=True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# log trasformation reduse impact to the outerlier.......ok prajwal 😄🧐

tips1['total_bill']=np.log10(tips1['total_bill'])
print(tips1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0      1.230193  1.01  Female     No   Sun  Dinner     2
# 1      1.014521  1.66    Male     No   Sun  Dinner     3
# 2      1.322426  3.50    Male     No   Sun  Dinner     3
# 3      1.374382  3.31    Male     No   Sun  Dinner     2
# 4      1.390759  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239    1.462847  5.92    Male     No   Sat  Dinner     3
# 240    1.434249  2.00  Female    Yes   Sat  Dinner     2
# 241    1.355452  2.00    Male    Yes   Sat  Dinner     2
# 242    1.250908  1.75    Male     No   Sat  Dinner     2
# 243    1.273696  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=tips1,x='day',y='total_bill')
plt.show()

# %%
sns.displot(tips1[tips['day']=='Fri']['total_bill'],kde=True)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=tips1,x='day',y='total_bill')
plt.show()

# %%
tips1.to_excel('C:\\Users\\HP\\Documents\\Batch 93 Day26\\tips.xlsx')
